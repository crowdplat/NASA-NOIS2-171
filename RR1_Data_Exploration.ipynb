# %%
import pandas as pd
import numpy as np
import PIL
from PIL import Image

Image.MAX_IMAGE_PIXELS = None

import os
import gzip
import zipfile
import requests
import matplotlib.pyplot as plt

# %%
base_url = "https://osdr.nasa.gov/osdr/data/osd/files/48.13"
headers = {"Accept": "application/json"}

response = requests.get(base_url, headers=headers)

if response.status_code == 200:
    print("Success")

    data = response.json()
# Out:
# Success

# %%
studies = data.get("studies", {})
osd_study = studies.get("OSD-48", {})
study_files = osd_study.get("study_files", [])

# study_files

# %%
if os.path.exists('rr1_dataset/csvs') and os.path.exists('rr1_dataset/img_input') and os.path.exists('rr1_dataset/tiff_input'):
    print("All directories exist. Skipping download.")
else:
    print("Some directories are missing. Running the download script.")

    # Check and download CSV files only if the 'csvs' directory is missing
    if not os.path.exists('rr1_dataset/csvs'):
        for file in study_files:
            if file.get('file_name').endswith('.csv'):
                file_name = file.get('file_name')
                file_url = f"https://osdr.nasa.gov{file.get('remote_url')}"

                save_dir = 'rr1_dataset/csvs'
                os.makedirs(save_dir, exist_ok=True)

                file_response = requests.get(file_url)
                if file_response.status_code == 200:
                    file_path = os.path.join(save_dir, file_name)
                    with open(file_path, "wb") as f:
                        f.write(file_response.content)
                    print(f"Saved: {file_path}")
                else:
                    print(f"Failed to download {file_name}: {file_response.status_code}\n")

    # Check and download JPG files only if the 'img_input' directory is missing
    if not os.path.exists('rr1_dataset/img_input'):
        for file in study_files:
            if file.get('file_name').endswith('.jpg'):
                file_name = file.get('file_name')
                file_url = f"https://osdr.nasa.gov{file.get('remote_url')}"

                save_dir = 'rr1_dataset/img_input'
                os.makedirs(save_dir, exist_ok=True)

                file_response = requests.get(file_url)
                if file_response.status_code == 200:
                    file_path = os.path.join(save_dir, file_name)
                    with open(file_path, "wb") as f:
                        f.write(file_response.content)
                    print(f"Saved: {file_path}")
                else:
                    print(f"Failed to download {file_name}: {file_response.status_code}\n")

    # Check and download TIFF files only if the 'tiff_input' directory is missing
    if not os.path.exists('rr1_dataset/tiff_input'):
        for file in study_files:
            if file.get('file_name').endswith('.tiff'):
                file_name = file.get('file_name')
                file_url = f"https://osdr.nasa.gov{file.get('remote_url')}"

                save_dir = 'rr1_dataset/tiff_input'
                os.makedirs(save_dir, exist_ok=True)

                file_response = requests.get(file_url)
                if file_response.status_code == 200:
                    file_path = os.path.join(save_dir, file_name)
                    with open(file_path, "wb") as f:
                        f.write(file_response.content)
                    print(f"Saved: {file_path}")
                else:
                    print(f"Failed to download {file_name}: {file_response.status_code}\n")
# Out:
# Directories missing. Running the download script.
# GLDS-48_rna_seq_contrasts.csv
# Downloading: GLDS-48_rna_seq_contrasts.csv
# Saved: rr1_dataset/csvs/GLDS-48_rna_seq_contrasts.csv
#
# GLDS-48_rna_seq_Normalized_Counts.csv
# Downloading: GLDS-48_rna_seq_Normalized_Counts.csv
# Saved: rr1_dataset/csvs/GLDS-48_rna_seq_Normalized_Counts.csv
#
# GLDS-48_rna_seq_differential_expression.csv
# Downloading: GLDS-48_rna_seq_differential_expression.csv
# Saved: rr1_dataset/csvs/GLDS-48_rna_seq_differential_expression.csv
#
# GLDS-48_rna_seq_bulkRNASeq_v1_runsheet.csv
# Downloading: GLDS-48_rna_seq_bulkRNASeq_v1_runsheet.csv
# Saved: rr1_dataset/csvs/GLDS-48_rna_seq_bulkRNASeq_v1_runsheet.csv
#
# GLDS-48_rna_seq_SampleTable.csv
# Downloading: GLDS-48_rna_seq_SampleTable.csv
# Saved: rr1_dataset/csvs/GLDS-48_rna_seq_SampleTable.csv
#
# LSDS-2_Histology_OSD_48_Histology_TRANSFORMED.csv
# Downloading: LSDS-2_Histology_OSD_48_Histology_TRANSFORMED.csv
# ...

# %%
rr1_label_dict = {
    'rr1_dataset/LSDS-2_Histology_M16-M17-M18_HE.jpg': 'Vivarium Control',
    'rr1_dataset/LSDS-2_Histology_M16-M17-M18_ORO.jpg': 'Vivarium Control',
    'rr1_dataset/LSDS-2_Histology_M19-M20_HE.jpg': 'Vivarium Control',
    'rr1_dataset/LSDS-2_Histology_M19-M20_ORO.jpg': 'Vivarium Control',
    'rr1_dataset/LSDS-2_Histology_M21-M22_HE.jpg': 'Space Flight',
    'rr1_dataset/LSDS-2_Histology_M21-M22_ORO.jpg': 'Space Flight',
    'rr1_dataset/LSDS-2_Histology_M25-M26-M27_HE.jpg': 'Space Flight',
    'rr1_dataset/LSDS-2_Histology_M25-M26-M27_ORO.jpg': 'Space Flight',
    'rr1_dataset/LSDS-2_Histology_M28-M30_HE.jpg' : 'Space Flight',
    'rr1_dataset/LSDS-2_Histology_M28-M30_ORO.jpg' : 'Space Flight',
    'rr1_dataset/LSDS-2_Histology_M28-M30_HE.jpg' : 'Space Flight',
    'rr1_dataset/LSDS-2_Histology_M31-M32_HE.jpg': 'Ground Control',
    'rr1_dataset/LSDS-2_Histology_M31-M32_ORO.jpg': 'Ground Control',
    'rr1_dataset/LSDS-2_Histology_M36-M37-M38_HE.jpg': 'Ground Control',
    'rr1_dataset/LSDS-2_Histology_M36-M37-M38_ORO.jpg': 'Ground Control',
    'rr1_dataset/LSDS-2_Histology_M39-M40_HE.jpg': 'Ground Control',
    'rr1_dataset/LSDS-2_Histology_M39-M40_ORO.jpg': 'Ground Control',
    'rr1_dataset/LSDS-2_Histology_M4-M5-M7_HE.jpg': 'Basal Control',
    'rr1_dataset/LSDS-2_Histology_M4-M5-M7_ORO.jpg': 'Basal Control',
    'rr1_dataset/LSDS-2_Histology_M8-M10_HE.jpg': 'Basal Control',
    'rr1_dataset/LSDS-2_Histology_M8-M10_ORO.jpg': 'Basal Control',
}

rr1_labels = pd.DataFrame(list(rr1_label_dict.items()), columns=['image_file_path', 'label'])

rr1_labels.head()
# Out:
#                                     image_file_path             label
# 0   rr1_dataset/LSDS-2_Histology_M16-M17-M18_HE.jpg  Vivarium Control
# 1  rr1_dataset/LSDS-2_Histology_M16-M17-M18_ORO.jpg  Vivarium Control
# 2       rr1_dataset/LSDS-2_Histology_M19-M20_HE.jpg  Vivarium Control
# 3      rr1_dataset/LSDS-2_Histology_M19-M20_ORO.jpg  Vivarium Control
# 4       rr1_dataset/LSDS-2_Histology_M21-M22_HE.jpg      Space Flight

# %%
output_folder = "rr1_dataset/preprocessed_images"
image_folder = "rr1_dataset/img_input"

# %%
os.makedirs(output_folder, exist_ok=True)
image_size = (224, 224)

# %%
# Example file

image_path = 'rr1_dataset/img_input/LSDS-2_Histology_M16-M17-M18_HE.jpg'

img = Image.open(image_path)

intermediate_size = (img.size[0] // 4, img.size[1] // 4)
img_intermediate = img.resize(intermediate_size, Image.Resampling.NEAREST)
img_resized = img_intermediate.resize(image_size, Image.Resampling.NEAREST)

img_array = np.array(img_resized) / 255.0

plt.imshow(img_array)
plt.show()

# %%
image_data = []
image_labels = []
import cv2

for _, row in rr1_labels.iterrows():
    file_name = row["image_file_path"]
    label = row["label"]

    file_path = os.path.join(image_folder, file_name)
    print(file_path)
    if os.path.exists(file_path):
        try:
            with Image.open(file_path) as img:
                img_gray = img.convert("L")
                
                img_array_gray = np.array(img_gray)

                # equalized_img_array = cv2.equalizeHist(img_array_gray)

                clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
                equalized_img_array = clahe.apply(img_array_gray)

                equalized_img = Image.fromarray(equalized_img_array)

                intermediate_size = (equalized_img.size[0] // 4, equalized_img.size[1] // 4)
                img_intermediate = equalized_img.resize(intermediate_size, Image.Resampling.NEAREST)
                img_resized = img_intermediate.resize(image_size, Image.Resampling.NEAREST)

                img_array = np.array(img_resized) / 255.0

                output_image_path = os.path.join(output_folder, f"{os.path.splitext(file_name)[0]}.npy")
                np.save(output_image_path, img_array)

                rr1_labels.loc[_, "processed_file_path"] = output_image_path

            del img_intermediate
            del img_resized
            del img_array

        except Exception as e:
            print(f"Error processing {file_name}: {e}")
